# %% [markdown]
# # Seaborn Titanic Project
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, focus on the plot itself).

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic dataset for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# * survival: un  Boolean indiquant si le passager a survécu ou non (0 = No; 1 = Yes); => target
# * pclass: Passenger class (1 = 1st; 2 = 2nd; 3 = 3rd)
# * sex: male/female
# * age: Age
# * sibsp: Nombre de frères et sœurs/conjoints
# * parch: Nombre de parents/enfants à bord
# * fare: Tarif passager (livre sterling)..
# * embarked: Port d’embarquement (C = Cherbourg; Q = Queenstown; S = Southampton)
# * class: la classe de voyage

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. Keep careful attention to the x and y labels**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
sns.displot(titanic['fare'])

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
sns.boxplot(x="class", y="age",hue="sex", data=titanic,palette='rainbow')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
sns.countplot(x='sex',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
numeric_df = titanic.select_dtypes(include=[np.number])
numeric_df = numeric_df.dropna()
sns.heatmap(numeric_df.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
#TBD
plt.figure()
plt.subplot(1,2,1)
sns.histplot(titanic[titanic['sex'] == 'male']['age'], bins=10, color='blue')
plt.title("Visualizing 'age' for all males")

plt.subplot(1,2,2)
sns.histplot(titanic[titanic['sex'] == 'female']['age'], bins=10, color='green')
plt.title("Visualizing 'age' for all females")
plt.show()

# %%
#we can use facetgrid to create all instance and combination of unique rows and columns
g = sns.FacetGrid(titanic,col = "sex")
g.map(plt.hist, "age", bins = 10)

# %%
help (g.map)
# Out:
# Help on method map in module seaborn.axisgrid:
#
# map(func, *args, **kwargs) method of seaborn.axisgrid.FacetGrid instance
#     Apply a plotting function to each facet's subset of the data.
#
#     Parameters
#     ----------
#     func : callable
#         A plotting function that takes data and keyword arguments. It
#         must plot to the currently active matplotlib Axes and take a
#         `color` keyword argument. If faceting on the `hue` dimension,
#         it must also take a `label` keyword argument.
#     args : strings
#         Column names in self.data that identify variables with data to
#         plot. The data for each variable is passed to `func` in the
#         order the variables are specified in the call.
#     kwargs : keyword arguments
#         All keyword arguments are passed to the plotting function.
#
#     Returns
#     -------
#     self : object
#         Returns self.
